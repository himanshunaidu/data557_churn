# %% [markdown]
# # Aim: To Run Lasso Regression on the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
import sklearn
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
import sys
import os
import math
import csv
import json

# %% [markdown]
# ## Helper Methods and Variables

# %%
def sentence_to_snake_case(sentence):
    # Split the sentence into words, convert to lowercase, and join with underscores
    snake_case = '_'.join(word.lower() for word in sentence.split())
    return snake_case

# %%
useless_cols = ['CustomerID', 'Count', 'Country', 'State', 'City', \
                'Zip Code', 'Lat Long', 'Churn Score', 'Churn Label', 'CLTV', 'Churn Reason', 'Total Charges']

# %%
y_cols = ['Churn Value', 'Tenure Months']

# %%
short_term_cols = ['Phone Service', 'Multiple Lines', 'Internet Service', \
                   'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', \
                   'Streaming TV', 'Streaming Movies']

# %% [markdown]
# ## Prepare the Data

# %%
os.getcwd()
# Out:
# 'C:\\D Drive\\University of Washington\\Study\\Quarter 2\\DATA 557\\Project\\ML'

# %%
data = pd.read_csv('../data/Telco_customer_churn_cleaned.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  CustomerID  Count        Country       State         City  \
# 0           0  3668-QPYBK      1  United States  California  Los Angeles
# 1           1  9237-HQITU      1  United States  California  Los Angeles
# 2           2  9305-CDSKC      1  United States  California  Los Angeles
# 3           3  7892-POOKP      1  United States  California  Los Angeles
# 4           4  0280-XJGEX      1  United States  California  Los Angeles
#
#    Zip Code                Lat Long   Latitude   Longitude  ...  \
# 0     90003  33.964131, -118.272783  33.964131 -118.272783  ...
# 1     90005   34.059281, -118.30742  34.059281 -118.307420  ...
# 2     90006  34.048013, -118.293953  34.048013 -118.293953  ...
# 3     90010  34.062125, -118.315709  34.062125 -118.315709  ...
# 4     90015  34.039224, -118.266293  34.039224 -118.266293  ...
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   Monthly Charges  Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0           53.85         108.15         Yes           1          86  3239
# 1           70.70         151.65         Yes           1          67  2701
# 2           99.65         820.50         Yes           1          86  5372
# 3          104.80        3046.05         Yes           1          84  5003
# 4          103.70        5036.30         Yes           1          89  5340
#
#                     Churn Reason
# 0   Competitor made better offer
# 1                          Moved
# 2                          Moved
# 3                          Moved
# 4  Competitor had better devices
#
# [5 rows x 34 columns]

# %%
data.head()
# Out:
#    Unnamed: 0  CustomerID  Count        Country       State         City  \
# 0           0  3668-QPYBK      1  United States  California  Los Angeles
# 1           1  9237-HQITU      1  United States  California  Los Angeles
# 2           2  9305-CDSKC      1  United States  California  Los Angeles
# 3           3  7892-POOKP      1  United States  California  Los Angeles
# 4           4  0280-XJGEX      1  United States  California  Los Angeles
#
#    Zip Code                Lat Long   Latitude   Longitude  ...  \
# 0     90003  33.964131, -118.272783  33.964131 -118.272783  ...
# 1     90005   34.059281, -118.30742  34.059281 -118.307420  ...
# 2     90006  34.048013, -118.293953  34.048013 -118.293953  ...
# 3     90010  34.062125, -118.315709  34.062125 -118.315709  ...
# 4     90015  34.039224, -118.266293  34.039224 -118.266293  ...
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   Monthly Charges  Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0           53.85         108.15         Yes           1          86  3239
# 1           70.70         151.65         Yes           1          67  2701
# 2           99.65         820.50         Yes           1          86  5372
# 3          104.80        3046.05         Yes           1          84  5003
# 4          103.70        5036.30         Yes           1          89  5340
#
#                     Churn Reason
# 0   Competitor made better offer
# 1                          Moved
# 2                          Moved
# 3                          Moved
# 4  Competitor had better devices
#
# [5 rows x 34 columns]

# %%
data.shape
# Out:
# (7043, 34)

# %%
data = data.rename(columns = lambda column: sentence_to_snake_case(column))

# %%
data.head()
# Out:
#    unnamed:_0  customerid  count        country       state         city  \
# 0           0  3668-QPYBK      1  United States  California  Los Angeles
# 1           1  9237-HQITU      1  United States  California  Los Angeles
# 2           2  9305-CDSKC      1  United States  California  Los Angeles
# 3           3  7892-POOKP      1  United States  California  Los Angeles
# 4           4  0280-XJGEX      1  United States  California  Los Angeles
#
#    zip_code                lat_long   latitude   longitude  ...  \
# 0     90003  33.964131, -118.272783  33.964131 -118.272783  ...
# 1     90005   34.059281, -118.30742  34.059281 -118.307420  ...
# 2     90006  34.048013, -118.293953  34.048013 -118.293953  ...
# 3     90010  34.062125, -118.315709  34.062125 -118.315709  ...
# 4     90015  34.039224, -118.266293  34.039224 -118.266293  ...
#
#          contract paperless_billing             payment_method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   monthly_charges  total_charges churn_label churn_value churn_score  cltv  \
# 0           53.85         108.15         Yes           1          86  3239
# 1           70.70         151.65         Yes           1          67  2701
# 2           99.65         820.50         Yes           1          86  5372
# 3          104.80        3046.05         Yes           1          84  5003
# 4          103.70        5036.30         Yes           1          89  5340
#
#                     churn_reason
# 0   Competitor made better offer
# 1                          Moved
# 2                          Moved
# 3                          Moved
# 4  Competitor had better devices
#
# [5 rows x 34 columns]

# %%
# Leaving in Customer ID just in case
useless_cols = [sentence_to_snake_case(column) for column in useless_cols]

# %%
y_cols = [sentence_to_snake_case(column) for column in y_cols]

# %%
y_cols
# Out:
# ['churn_value', 'tenure_months']

# %%
short_term_cols = [sentence_to_snake_case(column) for column in short_term_cols]

# %%
# short_term_cols

# %%
# Drop the first column "Unnamed" and the useless columns
data = data.drop([data.columns[0]] + useless_cols, axis=1)

# %%
data.head()
# Out:
#     latitude   longitude  gender senior_citizen partner dependents  \
# 0  33.964131 -118.272783    Male             No      No         No
# 1  34.059281 -118.307420  Female             No      No        Yes
# 2  34.048013 -118.293953  Female             No      No        Yes
# 3  34.062125 -118.315709  Female             No     Yes        Yes
# 4  34.039224 -118.266293    Male             No      No        Yes
#
#    tenure_months phone_service multiple_lines internet_service  ...  \
# 0              2           Yes             No              DSL  ...
# 1              2           Yes             No      Fiber optic  ...
# 2              8           Yes            Yes      Fiber optic  ...
# 3             28           Yes            Yes      Fiber optic  ...
# 4             49           Yes            Yes      Fiber optic  ...
#
#   online_backup device_protection tech_support streaming_tv streaming_movies  \
# 0           Yes                No           No           No               No
# 1            No                No           No           No               No
# 2            No               Yes           No          Yes              Yes
# 3            No               Yes          Yes          Yes              Yes
# 4           Yes               Yes           No          Yes              Yes
#
#          contract paperless_billing             payment_method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   monthly_charges  churn_value
# 0           53.85            1
# 1           70.70            1
# 2           99.65            1
# 3          104.80            1
# 4          103.70            1
#
# [5 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['latitude', 'longitude', 'gender', 'senior_citizen', 'partner',
#        'dependents', 'tenure_months', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'contract', 'paperless_billing', 'payment_method', 'monthly_charges',
#        'churn_value'],
#       dtype='object')

# %% [markdown]
# ## Divide the dataset into train and test test

# %%
RNG = np.random.RandomState(seed=420)

# %%
train, test = train_test_split(data, test_size=0.1, shuffle=True, random_state=RNG)

# %%
train.shape
# Out:
# (6338, 21)

# %%
test.shape
# Out:
# (705, 21)

# %% [markdown]
# ## Pre-process the data

# %% [markdown]
# ### Normalize
#
# **Remember to save normalization details of train data, to apply to test data**
#
# Pipeline transforms automatically do so for us.

# %%
dtypes = data.dtypes

# %%
# Prepare to Standardize all numeric columns except Churn Value
numeric_cols = list(data.select_dtypes(include=['int64', 'float64']))
numeric_cols = [column for column in numeric_cols if column not in y_cols]
numeric_cols
# Out:
# ['latitude', 'longitude', 'monthly_charges']

# %%
# Pipeline is to maintain consistency
standardization_transformer = Pipeline(steps=[('scaler', StandardScaler())])

# %%
# ColumnTransformer helps standardize only selected columns
preprocessor = ColumnTransformer(
    transformers=[('num', standardization_transformer, numeric_cols)],
    remainder='passthrough'  # This leaves the rest of the columns in the dataset unchanged
)

# %%
preprocessed_train_array = preprocessor.fit(train).transform(train)

# %%
# train

# %% [markdown]
# Convert the preprocessed arrays into pandas dataframe, by taking into account the correct column names, and the correct column types.

# %%
preprocessed_columns = [col.split('__')[1] for col in preprocessor.get_feature_names_out()]
# preprocessed_columns

# %% [markdown]
# ## Warning!! Bad Coding Practice Alert

# %%
# Instead of mapping preprocessed_columns with the old data.columns and getting the dtypes
# for now we will proceed with hard-coding logic
# Because columns that have prefix num are obviously float
# While other columns are either object or can be treated as object (except Churn Value which will separately be made int64)
preprocessed_column_types = ['float64' if col.split('__')[0]=='num' else 'object' for col in preprocessor.get_feature_names_out()]

# %%
preprocessed_column_types[-1] = 'int64'

# %%
preprocessed_column_dtypes = {preprocessed_columns[i]: preprocessed_column_types[i] for i in range(len(preprocessed_columns))}

# %%
preprocessed_train = pd.DataFrame(data=preprocessed_train_array, columns=preprocessed_columns)
preprocessed_train = preprocessed_train.astype(preprocessed_column_dtypes)

# %%
preprocessed_train.head()
# Out:
#    latitude  longitude  monthly_charges  gender senior_citizen partner  \
# 0 -0.498158  -0.371946         1.295086    Male             No     Yes
# 1 -1.423199   1.358143        -1.516232  Female             No      No
# 2  0.444907  -1.026476         0.965322    Male             No      No
# 3  1.202459  -0.117674        -1.514566  Female             No      No
# 4 -0.899465   0.660012         0.653879  Female             No      No
#
#   dependents tenure_months phone_service multiple_lines  ...  \
# 0        Yes            60           Yes            Yes  ...
# 1         No            20           Yes             No  ...
# 2         No            17           Yes             No  ...
# 3         No            29           Yes             No  ...
# 4         No            49           Yes            Yes  ...
#
#        online_security        online_backup    device_protection  \
# 0                   No                  Yes                   No
# 1  No internet service  No internet service  No internet service
# 2                  Yes                   No                   No
# 3  No internet service  No internet service  No internet service
# 4                   No                   No                   No
#
#           tech_support         streaming_tv     streaming_movies  \
# 0                  Yes                  Yes                  Yes
# 1  No internet service  No internet service  No internet service
# 2                   No                  Yes                  Yes
# 3  No internet service  No internet service  No internet service
# 4                   No                   No                  Yes
#
#          contract paperless_billing             payment_method churn_value
# 0  Month-to-month               Yes  Bank transfer (automatic)           0
# 1        One year               Yes    Credit card (automatic)           0
# 2  Month-to-month                No           Electronic check           1
# 3        Two year                No               Mailed check           0
# 4  Month-to-month               Yes           Electronic check           0
#
# [5 rows x 21 columns]

# %%
# preprocessed_train.dtypes

# %%
preprocessed_test_array = preprocessor.transform(test)

# %%
preprocessed_test = pd.DataFrame(data=preprocessed_test_array, columns=preprocessed_columns)
preprocessed_test = preprocessed_test.astype(preprocessed_column_dtypes)

# %%
preprocessed_test.head()
# Out:
#    latitude  longitude  monthly_charges  gender senior_citizen partner  \
# 0  1.077896  -1.383298         1.331726  Female            Yes     Yes
# 1 -0.903949   0.703809        -1.479591    Male             No      No
# 2 -0.863037   0.738054        -0.165534    Male             No      No
# 3  0.495985  -1.031974         0.868725  Female            Yes      No
# 4  0.898898  -0.799467         0.184215  Female             No      No
#
#   dependents tenure_months phone_service multiple_lines  ...  \
# 0         No            62           Yes            Yes  ...
# 1         No            47           Yes             No  ...
# 2         No             9           Yes            Yes  ...
# 3         No            32           Yes             No  ...
# 4         No             4           Yes             No  ...
#
#        online_security        online_backup    device_protection  \
# 0                  Yes                   No                  Yes
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#           tech_support         streaming_tv     streaming_movies  \
# 0                   No                  Yes                  Yes
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                  Yes
# 3                   No                  Yes                  Yes
# 4                   No                   No                   No
#
#          contract paperless_billing             payment_method churn_value
# 0        One year               Yes           Electronic check           0
# 1        Two year                No  Bank transfer (automatic)           0
# 2  Month-to-month                No               Mailed check           0
# 3  Month-to-month                No           Electronic check           0
# 4  Month-to-month                No           Electronic check           1
#
# [5 rows x 21 columns]

# %%
# preprocessed_test.dtypes

# %% [markdown]
# ### Split Datasets into X and y
#
# (Not useful if using statsmodels api)

# %%
X_columns = list(preprocessed_train.columns)

# %%
X_columns = [column for column in X_columns if column not in y_cols]

# %%
# X_columns

# %%
X_train, y_train = preprocessed_train[X_columns], preprocessed_train[y_cols]

# %%
X_test, y_test = preprocessed_test[X_columns], preprocessed_test[y_cols]

# %% [markdown]
# ### Dimensionality Reduction?
#
# Maybe later. Not relevant to Lasso Regression

# %% [markdown]
# ## Run Full and Reduced Model LRT Test

# %%
# preprocessed_column_types

# %%
# preprocessed_train_array

# %%
# preprocessed_train.dtypes

# %%
preprocessed_train.columns
# Out:
# Index(['latitude', 'longitude', 'monthly_charges', 'gender', 'senior_citizen',
#        'partner', 'dependents', 'tenure_months', 'phone_service',
#        'multiple_lines', 'internet_service', 'online_security',
#        'online_backup', 'device_protection', 'tech_support', 'streaming_tv',
#        'streaming_movies', 'contract', 'paperless_billing', 'payment_method',
#        'churn_value'],
#       dtype='object')

# %%
def formulaGenerator(data, y_col = ['']):
    x_cols = [column for column in list(data.columns) if column not in y_col]
    formula = f'{y_col[0]} ~'
    for index, column in enumerate(x_cols):
        if index != 0: formula = f'{formula} +'
        if data.dtypes[column] in ['int64', 'float64']: formula = f'{formula} {column}'
        else: formula = f'{formula} C({column})'
    return formula

# %%
formula_full = formulaGenerator(preprocessed_train, y_col)
formula_full
# Out:
# 'churn_value ~ latitude + longitude + tenure_months + monthly_charges + C(gender) + C(senior_citizen) + C(partner) + C(dependents) + C(phone_service) + C(multiple_lines) + C(internet_service) + C(online_security) + C(online_backup) + C(device_protection) + C(tech_support) + C(streaming_tv) + C(streaming_movies) + C(contract) + C(paperless_billing) + C(payment_method)'

# %%
long_term_cols = [column for column in preprocessed_train.columns if column not in short_term_cols]
# long_term_cols

# %%
formula_reduced = formulaGenerator(preprocessed_train[long_term_cols], y_col)
formula_reduced
# Out:
# 'churn_value ~ latitude + longitude + tenure_months + monthly_charges + C(gender) + C(senior_citizen) + C(partner) + C(dependents) + C(contract) + C(paperless_billing) + C(payment_method)'

# %%
model_full = smf.logit(formula = formula_full, data = preprocessed_train)
# results_full = model_full.fit_regularized(method='l1', alpha=0.01, QC_verbose=False)
results_full = model_full.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.400788
#          Iterations 8

# %%
model_reduced = smf.logit(formula = formula_reduced, data = preprocessed_train)
results_reduced = model_reduced.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.410337
#          Iterations 8

# %%
results_full.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            churn_value   No. Observations:                 6338
# Model:                          Logit   Df Residuals:                     6313
# Method:                           MLE   Df Model:                           24
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.3066
# Time:                        18:54:15   Log-Likelihood:                -2540.2
# converged:                       True   LL-Null:                       -3663.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ================================================================================================================
#                                                    coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                       -1.4714        nan        nan        nan         nan         nan
# C(gender)[T.Male]                               -0.0388      0.065     -0.593      0.553      -0.167       0.090
# C(senior_citizen)[T.Yes]                         0.1239      0.084      1.475      0.140      -0.041       0.288
# C(partner)[T.Yes]                                0.2254      0.078      2.892      0.004       0.073       0.378
# C(dependents)[T.Yes]                            -1.5236      0.125    -12.205      0.000      -1.768      -1.279
# C(phone_service)[T.Yes]                         -0.7475        nan        nan        nan         nan         nan
# C(multiple_lines)[T.No phone service]           -0.7240    9.2e+06  -7.87e-08      1.000    -1.8e+07     1.8e+07
# C(multiple_lines)[T.Yes]                         0.4347      0.138      3.158      0.002       0.165       0.705
# C(internet_service)[T.Fiber optic]               1.4545        nan        nan        nan         nan         nan
# C(internet_service)[T.No]                       -0.1948   6.58e+15  -2.96e-17      1.000   -1.29e+16    1.29e+16
# C(online_security)[T.No internet service]       -0.1948   1.03e+07  -1.89e-08      1.000   -2.02e+07    2.02e+07
# C(online_security)[T.Yes]                       -0.1924      0.288     -0.669      0.504      -0.756       0.371
# C(online_backup)[T.No internet service]         -0.1948   1.15e+07   -1.7e-08      1.000   -2.25e+07    2.25e+07
# C(online_backup)[T.Yes]                          0.0353      0.176      0.201      0.841      -0.310       0.381
# C(device_protection)[T.No internet service]     -0.1948   1.15e+07   -1.7e-08      1.000   -2.25e+07    2.25e+07
# C(device_protection)[T.Yes]                      0.0789      0.242      0.326      0.744      -0.395       0.553
# C(tech_support)[T.No internet service]          -0.1948        nan        nan        nan         nan         nan
# C(tech_support)[T.Yes]                          -0.1905      0.296     -0.643      0.520      -0.771       0.390
# C(streaming_tv)[T.No internet service]          -0.1948        nan        nan        nan         nan         nan
# C(streaming_tv)[T.Yes]                           0.5142      0.052      9.828      0.000       0.412       0.617
# C(streaming_movies)[T.No internet service]      -0.1948   5.83e+08  -3.34e-10      1.000   -1.14e+09    1.14e+09
# C(streaming_movies)[T.Yes]                       0.5169        nan        nan        nan         nan         nan
# C(contract)[T.One year]                         -0.6784      0.124     -5.469      0.000      -0.921      -0.435
# C(contract)[T.Two year]                         -1.2582      0.195     -6.459      0.000      -1.640      -0.876
# C(paperless_billing)[T.Yes]                      0.3302      0.084      3.952      0.000       0.166       0.494
# C(payment_method)[T.Credit card (automatic)]    -0.0529      0.143     -0.370      0.711      -0.333       0.227
# C(payment_method)[T.Electronic check]            0.3709        nan        nan        nan         nan         nan
# C(payment_method)[T.Mailed check]                0.0113      0.168      0.067      0.946      -0.318       0.341
# latitude                                        -0.0697      0.073     -0.950      0.342      -0.214       0.074
# longitude                                       -0.0685      0.073     -0.935      0.350      -0.212       0.075
# tenure_months                                   -0.8555      0.058    -14.785      0.000      -0.969      -0.742
# monthly_charges                                 -0.7254      0.784     -0.926      0.355      -2.262       0.811
# ================================================================================================================
# """

# %% [markdown]
# ## Warning!! Bad Coding Practice Alert
#
# Hard-coding of which coefficients to test

# %%
null_hypothesis_coefs = list(results_full.params[6:22].index)
null_hypothesis_coefs

null_hypothesis_wald = ','.join([f'{coeff} = 0' for coeff in null_hypothesis_coefs])
null_hypothesis_wald = 'longitude = 0'

# %%
wald_test1_summary = results_full.wald_test(null_hypothesis_wald, use_f = False)

# %%
wald_test1_summary
# Out:
# <class 'statsmodels.stats.contrast.ContrastResults'>
# <Wald test (chi2): statistic=[[0.87357652]], p-value=0.3499670762145105, df_denom=1>

# %%
# model_reduced = smf.glm(formula=formula_reduced, family=sm.families.Binomial(), data=preprocessed_train)
# results_reduced = model_reduced.fit()

# %%
# model_0 = smf.glm(formula="churn_value ~ latitude + longitude + tenure_months + monthly_charges + total_charges", \
#                  family=sm.families.Binomial(), data=preprocessed_train)

# %%
# sm.stats.

# %%
# results.summary()

# %%
param_grid = {'alpha': np.logspace(-5, 3, 10)}

# %%
param_list = list(ParameterGrid(param_grid))

# %%
param_list
# Out:
# [{'alpha': 1e-05},
#  {'alpha': 7.742636826811278e-05},
#  {'alpha': 0.0005994842503189409},
#  {'alpha': 0.004641588833612777},
#  {'alpha': 0.03593813663804626},
#  {'alpha': 0.2782559402207126},
#  {'alpha': 2.154434690031882},
#  {'alpha': 16.681005372000556},
#  {'alpha': 129.15496650148827},
#  {'alpha': 1000.0}]

# %%
coefficients = None

# %%
for params in param_list:
    # Fit the model with the given parameters
    try:
        results = model.fit_regularized(method='l1', QC_verbose=False, **params)
    except:
        print(params)
    
    # Store the coefficients
    row = pd.DataFrame(results.params).transpose()
    row = pd.concat([row, pd.DataFrame.from_dict({'regularization': [params['alpha']]})], axis=1)
    if coefficients is None: 
        coefficients = row
    else: 
        coefficients = pd.concat([coefficients, row], ignore_index=True)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.39888452593551926
#             Iterations: 160
#             Function evaluations: 161
#             Gradient evaluations: 160
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:71: ConvergenceWarning: QC check did not pass for 32 out of 33 parameters
# Try increasing solver accuracy or number of iterations, decreasing alpha, or switch solvers
#   warnings.warn(message, ConvergenceWarning)
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:144: ConvergenceWarning: Could not trim params automatically due to failed QC check. Trimming using trim_mode == 'size' will still work.
#   warnings.warn(msg, ConvergenceWarning)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.39888497899903125
#             Iterations: 161
#             Function evaluations: 161
#             Gradient evaluations: 161
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:71: ConvergenceWarning: QC check did not pass for 23 out of 33 parameters
# Try increasing solver accuracy or number of iterations, decreasing alpha, or switch solvers
#   warnings.warn(message, ConvergenceWarning)
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:144: ConvergenceWarning: Could not trim params automatically due to failed QC check. Trimming using trim_mode == 'size' will still work.
#   warnings.warn(msg, ConvergenceWarning)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.39888844198564705
#             Iterations: 161
#             Function evaluations: 162
#             Gradient evaluations: 161
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:71: ConvergenceWarning: QC check did not pass for 24 out of 33 parameters
# Try increasing solver accuracy or number of iterations, decreasing alpha, or switch solvers
#   warnings.warn(message, ConvergenceWarning)
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:144: ConvergenceWarning: Could not trim params automatically due to failed QC check. Trimming using trim_mode == 'size' will still work.
#   warnings.warn(msg, ConvergenceWarning)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3988979227308406
#             Iterations: 327
#             Function evaluations: 327
#             Gradient evaluations: 327
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:71: ConvergenceWarning: QC check did not pass for 11 out of 33 parameters
# Try increasing solver accuracy or number of iterations, decreasing alpha, or switch solvers
#   warnings.warn(message, ConvergenceWarning)
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:144: ConvergenceWarning: Could not trim params automatically due to failed QC check. Trimming using trim_mode == 'size' will still work.
#   warnings.warn(msg, ConvergenceWarning)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.39897327954211337
#             Iterations: 473
#             Function evaluations: 473
#             Gradient evaluations: 473
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:71: ConvergenceWarning: QC check did not pass for 10 out of 33 parameters
# Try increasing solver accuracy or number of iterations, decreasing alpha, or switch solvers
#   warnings.warn(message, ConvergenceWarning)
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:144: ConvergenceWarning: Could not trim params automatically due to failed QC check. Trimming using trim_mode == 'size' will still work.
#   warnings.warn(msg, ConvergenceWarning)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3994726908543385
#             Iterations: 329
#             Function evaluations: 329
#             Gradient evaluations: 329
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:71: ConvergenceWarning: QC check did not pass for 3 out of 33 parameters
# Try increasing solver accuracy or number of iterations, decreasing alpha, or switch solvers
#   warnings.warn(message, ConvergenceWarning)
# C:\Users\hnaid\anaconda3\Lib\site-packages\statsmodels\base\l1_solvers_common.py:144: ConvergenceWarning: Could not trim params automatically due to failed QC check. Trimming using trim_mode == 'size' will still work.
#   warnings.warn(msg, ConvergenceWarning)
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.40270307787397003
#             Iterations: 181
#             Function evaluations: 181
#             Gradient evaluations: 181
# {'alpha': 2.154434690031882}
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.4228194369374018
#             Iterations: 106
#             Function evaluations: 106
#             Gradient evaluations: 106
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5126442275529539
#             Iterations: 63
#             Function evaluations: 63
#             Gradient evaluations: 63
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6810957254983847
#             Iterations: 8
#             Function evaluations: 8
#             Gradient evaluations: 8

# %%
coefficients
# Out:
#    Intercept  C(gender)[T.Male]  C(senior_citizen)[T.Yes]  C(partner)[T.Yes]  \
# 0  -1.532137          -0.042548                  0.121027           0.233722
# 1  -1.530028          -0.042554                  0.121047           0.233724
# 2  -1.518520          -0.042605                  0.121061           0.233751
# 3  -1.461593          -0.042558                  0.121015           0.233625
# 4  -1.393737          -0.042748                  0.120721           0.233554
# 5  -0.936041          -0.043427                  0.119222           0.232149
# 6  -0.936041          -0.043427                  0.119222           0.232149
# 7   0.000000           0.000000                  0.070090           0.033434
# 8  -0.494062           0.000000                  0.000000           0.000000
# 9  -0.312390           0.000000                  0.000000           0.000000
#
#    C(dependents)[T.Yes]  C(phone_service)[T.Yes]  \
# 0             -1.516276                -0.714543
# 1             -1.516289                -0.715183
# 2             -1.516371                -0.715307
# 3             -1.516290                -0.785738
# 4             -1.516265                -0.740597
# 5             -1.515018                -0.665525
# 6             -1.515018                -0.665525
# 7             -1.278034                -0.955429
# 8             -0.569859                -0.463635
# 9              0.000000                 0.000000
#
#    C(multiple_lines)[T.No phone service]  C(multiple_lines)[T.Yes]  \
# 0                          -6.912556e-01                  0.412923
# 1                          -6.903996e-01                  0.412555
# 2                          -6.788854e-01                  0.409708
# 3                          -7.634952e-01                  0.413120
# 4                          -6.048521e-01                  0.384660
# 5                           1.572580e-16                  0.250083
# 6                           1.572580e-16                  0.250083
# 7                           0.000000e+00                  0.028802
# 8                           0.000000e+00                  0.000000
# 9                           0.000000e+00                  0.000000
#
#    C(internet_service)[T.Fiber optic]  C(internet_service)[T.No]  ...  \
# 0                            1.476520                  -0.221773  ...
# 1                            1.474686                  -0.221510  ...
# 2                            1.460460                  -0.219466  ...
# 3                            1.477834                  -0.221938  ...
# 4                            1.336433                  -0.201636  ...
# 5                            0.671384                  -0.105932  ...
# 6                            0.671384                  -0.105932  ...
# 7                            0.013137                   0.000000  ...
# 8                            0.000000                   0.000000  ...
# 9                            0.000000                   0.000000  ...
#
#    C(paperless_billing)[T.Yes]  C(payment_method)[T.Credit card (automatic)]  \
# 0                     0.337039                                     -0.052405
# 1                     0.337031                                     -0.052412
# 2                     0.337034                                     -0.052464
# 3                     0.336954                                     -0.052550
# 4                     0.336985                                     -0.052150
# 5                     0.336505                                     -0.050044
# 6                     0.336505                                     -0.050044
# 7                     0.221462                                      0.000000
# 8                     0.000000                                      0.000000
# 9                     0.000000                                      0.000000
#
#    C(payment_method)[T.Electronic check]  C(payment_method)[T.Mailed check]  \
# 0                               0.362391                          -0.050153
# 1                               0.362387                          -0.050155
# 2                               0.362353                          -0.050199
# 3                               0.362307                          -0.050182
# 4                               0.362496                          -0.049809
# 5                               0.363601                          -0.047165
# 6                               0.363601                          -0.047165
# 7                               0.341074                           0.000000
# 8                               0.041925                           0.000000
# 9                               0.000000                           0.000000
#
#    latitude  longitude  tenure_months  monthly_charges  total_charges  \
# 0 -0.069585  -0.069243      -1.568747    -9.720517e-01   8.243054e-01
# 1 -0.069589  -0.069248      -1.568742    -9.698446e-01   8.243028e-01
# 2 -0.069660  -0.069330      -1.568700    -9.527031e-01   8.242705e-01
# 3 -0.069523  -0.069178      -1.567754    -9.733694e-01   8.233295e-01
# 4 -0.069238  -0.068985      -1.565603    -8.029802e-01   8.212667e-01
# 5 -0.066909  -0.067103      -1.546036    -1.342996e-16   8.015591e-01
# 6 -0.066909  -0.067103      -1.546036    -1.342996e-16   8.015591e-01
# 7  0.000000   0.000000      -0.817346     9.145200e-01   9.701658e-17
# 8  0.000000   0.000000      -0.883312     6.955048e-01   0.000000e+00
# 9  0.000000   0.000000       0.000000     0.000000e+00   0.000000e+00
#
#    regularization
# 0        0.000010
# 1        0.000077
# 2        0.000599
# 3        0.004642
# 4        0.035938
# 5        0.278256
# 6        2.154435
# 7       16.681005
# 8      129.154967
# 9     1000.000000
#
# [10 rows x 34 columns]

# %%
coefficients.plot(x='regularization', logx=True, xlabel='Regularization Value', ylabel='Coefficient Value', kind='line', legend=False)
plt.axhline(y=0, color='black', linestyle='--')
plt.axvline(x=16, color='blue', linestyle='--')
plt.show()

# %% [markdown]
# ## Helper Methods for Logistic Regression, Cross-Validation

# %% [markdown]
# # Aim: To Detect Correlation, and Extract Non-Correlated Variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import scipy
import seaborn as sns

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
import sklearn
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
import sys
import os
import math
import csv
import json

# %% [markdown]
# ## Helper Methods and Variables

# %%
def sentence_to_snake_case(sentence):
    # Split the sentence into words, convert to lowercase, and join with underscores
    snake_case = '_'.join(word.lower() for word in sentence.split())
    return snake_case

# %%
useless_cols = ['CustomerID', 'Count', 'Country', 'State', 'City', \
                'Zip Code', 'Lat Long', 'Churn Score', 'Churn Label', 'CLTV', 'Churn Reason', 'Total Charges']

# %%
y_cols = ['Churn Value', 'Tenure Months']

# %%
short_term_cols = ['Phone Service', 'Multiple Lines', 'Internet Service', \
                   'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', \
                   'Streaming TV', 'Streaming Movies']

# %% [markdown]
# ## Prepare the data

# %%
os.getcwd()
# Out:
# 'C:\\D Drive\\University of Washington\\Study\\Quarter 2\\DATA 557\\Project\\ML'

# %%
data = pd.read_csv('../data/Telco_customer_churn_cleaned.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  CustomerID  Count        Country       State         City  \
# 0           0  3668-QPYBK      1  United States  California  Los Angeles
# 1           1  9237-HQITU      1  United States  California  Los Angeles
# 2           2  9305-CDSKC      1  United States  California  Los Angeles
# 3           3  7892-POOKP      1  United States  California  Los Angeles
# 4           4  0280-XJGEX      1  United States  California  Los Angeles
#
#    Zip Code                Lat Long   Latitude   Longitude  ...  \
# 0     90003  33.964131, -118.272783  33.964131 -118.272783  ...
# 1     90005   34.059281, -118.30742  34.059281 -118.307420  ...
# 2     90006  34.048013, -118.293953  34.048013 -118.293953  ...
# 3     90010  34.062125, -118.315709  34.062125 -118.315709  ...
# 4     90015  34.039224, -118.266293  34.039224 -118.266293  ...
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   Monthly Charges  Total Charges Churn Label Churn Value Churn Score  CLTV  \
# 0           53.85         108.15         Yes           1          86  3239
# 1           70.70         151.65         Yes           1          67  2701
# 2           99.65         820.50         Yes           1          86  5372
# 3          104.80        3046.05         Yes           1          84  5003
# 4          103.70        5036.30         Yes           1          89  5340
#
#                     Churn Reason
# 0   Competitor made better offer
# 1                          Moved
# 2                          Moved
# 3                          Moved
# 4  Competitor had better devices
#
# [5 rows x 34 columns]

# %%
data = data.rename(columns = lambda column: sentence_to_snake_case(column))

# %%
data.head()
# Out:
#    unnamed:_0  customerid  count        country       state         city  \
# 0           0  3668-QPYBK      1  United States  California  Los Angeles
# 1           1  9237-HQITU      1  United States  California  Los Angeles
# 2           2  9305-CDSKC      1  United States  California  Los Angeles
# 3           3  7892-POOKP      1  United States  California  Los Angeles
# 4           4  0280-XJGEX      1  United States  California  Los Angeles
#
#    zip_code                lat_long   latitude   longitude  ...  \
# 0     90003  33.964131, -118.272783  33.964131 -118.272783  ...
# 1     90005   34.059281, -118.30742  34.059281 -118.307420  ...
# 2     90006  34.048013, -118.293953  34.048013 -118.293953  ...
# 3     90010  34.062125, -118.315709  34.062125 -118.315709  ...
# 4     90015  34.039224, -118.266293  34.039224 -118.266293  ...
#
#          contract paperless_billing             payment_method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   monthly_charges  total_charges churn_label churn_value churn_score  cltv  \
# 0           53.85         108.15         Yes           1          86  3239
# 1           70.70         151.65         Yes           1          67  2701
# 2           99.65         820.50         Yes           1          86  5372
# 3          104.80        3046.05         Yes           1          84  5003
# 4          103.70        5036.30         Yes           1          89  5340
#
#                     churn_reason
# 0   Competitor made better offer
# 1                          Moved
# 2                          Moved
# 3                          Moved
# 4  Competitor had better devices
#
# [5 rows x 34 columns]

# %%
# Leaving in Customer ID just in case
useless_cols = [sentence_to_snake_case(column) for column in useless_cols]

# %%
y_cols = [sentence_to_snake_case(column) for column in y_cols]

# %%
y_cols
# Out:
# ['churn_value', 'tenure_months']

# %%
# Drop the first column "Unnamed" and the useless columns
data = data.drop([data.columns[0]] + useless_cols, axis=1)

# %%
data.head()
# Out:
#     latitude   longitude  gender senior_citizen partner dependents  \
# 0  33.964131 -118.272783    Male             No      No         No
# 1  34.059281 -118.307420  Female             No      No        Yes
# 2  34.048013 -118.293953  Female             No      No        Yes
# 3  34.062125 -118.315709  Female             No     Yes        Yes
# 4  34.039224 -118.266293    Male             No      No        Yes
#
#    tenure_months phone_service multiple_lines internet_service  ...  \
# 0              2           Yes             No              DSL  ...
# 1              2           Yes             No      Fiber optic  ...
# 2              8           Yes            Yes      Fiber optic  ...
# 3             28           Yes            Yes      Fiber optic  ...
# 4             49           Yes            Yes      Fiber optic  ...
#
#   online_backup device_protection tech_support streaming_tv streaming_movies  \
# 0           Yes                No           No           No               No
# 1            No                No           No           No               No
# 2            No               Yes           No          Yes              Yes
# 3            No               Yes          Yes          Yes              Yes
# 4           Yes               Yes           No          Yes              Yes
#
#          contract paperless_billing             payment_method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   monthly_charges  churn_value
# 0           53.85            1
# 1           70.70            1
# 2           99.65            1
# 3          104.80            1
# 4          103.70            1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Get either the best case or worst case scenario
#
# ### The data being set from here will decide how the model will treat its unknown churn customers

# %% [markdown]
# **Our y is a check on whether the user will churn within 12 months or not**

# %%
def best_case_churn(row):
    # User has definitely not churned within the 12 months
    if row['tenure_months'] >= 12: return 0
    # User has definitely churned within the 12 months
    if row['tenure_months'] < 12 and row['churn_value'] == 1: return 1
    # Best case assumption
    return 0

# %%
def worst_case_churn(row):
    # User has definitely not churned within the 12 months
    if row['tenure_months'] >= 12: return 0
    # User has definitely churned within the 12 months
    if row['tenure_months'] < 12 and row['churn_value'] == 1: return 1
    # Best case assumption
    return 1

# %% [markdown]
# ### Switch the following line to switch between best case and worst case

# %%
main_y_col = 'churn'

# %%
data[main_y_col] = data.apply(worst_case_churn, axis=1)

# %%
data['tenure_months'].unique()
# Out:
# array([ 2,  8, 28, 49, 10,  1, 47, 17,  5, 34, 11, 15, 18,  9,  7, 12, 25,
#        68, 55, 37,  3, 27, 20,  4, 58, 53, 13,  6, 19, 59, 16, 52, 24, 32,
#        38, 54, 43, 63, 21, 69, 22, 61, 60, 48, 40, 23, 39, 35, 56, 65, 33,
#        30, 45, 46, 62, 70, 50, 44, 71, 26, 14, 41, 66, 64, 29, 42, 67, 51,
#        31, 57, 36, 72,  0], dtype=int64)

# %%
y_cols.extend([main_y_col])
y_cols
# Out:
# ['churn_value', 'tenure_months', 'churn']

# %%
y_cols
# Out:
# ['churn_value', 'tenure_months', 'churn']

# %% [markdown]
# ## Divide the dataset into train and test test

# %%
RNG = np.random.RandomState(seed=420)

# %%
train, test = train_test_split(data, test_size=0.1, shuffle=True, random_state=RNG)

# %%
train.shape
# Out:
# (6338, 22)

# %%
test.shape
# Out:
# (705, 22)

# %% [markdown]
# ## Save the dataset

# %%
# data.to_csv('./data/ml_best_case.csv')

# %% [markdown]
# ## Pre-process the data

# %% [markdown]
# ### Normalize
#
# **Remember to save normalization details of train data, to apply to test data**
#
# Pipeline transforms automatically do so for us.

# %%
# Prepare to Standardize all numeric columns except Churn Value
numeric_cols = list(data.select_dtypes(include=['int64', 'float64']))
numeric_cols = [column for column in numeric_cols if column not in y_cols]
numeric_cols
# Out:
# ['latitude', 'longitude', 'monthly_charges']

# %%
# Pipeline is to maintain consistency
standardization_transformer = Pipeline(steps=[('scaler', StandardScaler())])

# %%
# ColumnTransformer helps standardize only selected columns
preprocessor = ColumnTransformer(
    transformers=[('num', standardization_transformer, numeric_cols)],
    remainder='passthrough'  # This leaves the rest of the columns in the dataset unchanged
)

# %%
preprocessed_train_array = preprocessor.fit(train).transform(train)

# %%
preprocessed_columns = [col.split('__')[1] for col in preprocessor.get_feature_names_out()]
# preprocessed_columns

# %% [markdown]
# ## Warning!! Bad Coding Practice Alert

# %%
final_columns = [column for column in train.columns if (column not in y_cols or column == main_y_col)]
# final_columns

# %%
# Instead of mapping preprocessed_columns with the old data.columns and getting the dtypes
# for now we will proceed with hard-coding logic
# Because columns that have prefix num are obviously float
# While other columns are either object or can be treated as object (except Churn Value which will separately be made int64)
preprocessed_column_types = ['float64' if col.split('__')[0]=='num' else 'object' for col in preprocessor.get_feature_names_out()]

# %%
preprocessed_column_types[-1] = 'int64'

# %%
preprocessed_column_dtypes = {preprocessed_columns[i]: preprocessed_column_types[i] for i in range(len(preprocessed_columns))}

# %%
preprocessed_train = pd.DataFrame(data=preprocessed_train_array, columns=preprocessed_columns)
preprocessed_train = preprocessed_train.astype(preprocessed_column_dtypes)

# %%
preprocessed_train.head()
# Out:
#    latitude  longitude  monthly_charges  gender senior_citizen partner  \
# 0 -0.498158  -0.371946         1.295086    Male             No     Yes
# 1 -1.423199   1.358143        -1.516232  Female             No      No
# 2  0.444907  -1.026476         0.965322    Male             No      No
# 3  1.202459  -0.117674        -1.514566  Female             No      No
# 4 -0.899465   0.660012         0.653879  Female             No      No
#
#   dependents tenure_months phone_service multiple_lines  ...  \
# 0        Yes            60           Yes            Yes  ...
# 1         No            20           Yes             No  ...
# 2         No            17           Yes             No  ...
# 3         No            29           Yes             No  ...
# 4         No            49           Yes            Yes  ...
#
#          online_backup    device_protection         tech_support  \
# 0                  Yes                   No                  Yes
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                   No
# 3  No internet service  No internet service  No internet service
# 4                   No                   No                   No
#
#           streaming_tv     streaming_movies        contract paperless_billing  \
# 0                  Yes                  Yes  Month-to-month               Yes
# 1  No internet service  No internet service        One year               Yes
# 2                  Yes                  Yes  Month-to-month                No
# 3  No internet service  No internet service        Two year                No
# 4                   No                  Yes  Month-to-month               Yes
#
#               payment_method churn_value churn
# 0  Bank transfer (automatic)           0     0
# 1    Credit card (automatic)           0     0
# 2           Electronic check           1     0
# 3               Mailed check           0     0
# 4           Electronic check           0     0
#
# [5 rows x 22 columns]

# %%
preprocessed_train = preprocessed_train[final_columns]

# %%
preprocessed_test_array = preprocessor.transform(test)

# %%
preprocessed_test = pd.DataFrame(data=preprocessed_test_array, columns=preprocessed_columns)
preprocessed_test = preprocessed_test.astype(preprocessed_column_dtypes)

# %%
preprocessed_test.head()
# Out:
#    latitude  longitude  monthly_charges  gender senior_citizen partner  \
# 0  1.077896  -1.383298         1.331726  Female            Yes     Yes
# 1 -0.903949   0.703809        -1.479591    Male             No      No
# 2 -0.863037   0.738054        -0.165534    Male             No      No
# 3  0.495985  -1.031974         0.868725  Female            Yes      No
# 4  0.898898  -0.799467         0.184215  Female             No      No
#
#   dependents tenure_months phone_service multiple_lines  ...  \
# 0         No            62           Yes            Yes  ...
# 1         No            47           Yes             No  ...
# 2         No             9           Yes            Yes  ...
# 3         No            32           Yes             No  ...
# 4         No             4           Yes             No  ...
#
#          online_backup    device_protection         tech_support  \
# 0                   No                  Yes                   No
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#           streaming_tv     streaming_movies        contract paperless_billing  \
# 0                  Yes                  Yes        One year               Yes
# 1  No internet service  No internet service        Two year                No
# 2                   No                  Yes  Month-to-month                No
# 3                  Yes                  Yes  Month-to-month                No
# 4                   No                   No  Month-to-month                No
#
#               payment_method churn_value churn
# 0           Electronic check           0     0
# 1  Bank transfer (automatic)           0     0
# 2               Mailed check           0     1
# 3           Electronic check           0     0
# 4           Electronic check           1     1
#
# [5 rows x 22 columns]

# %%
preprocessed_test = preprocessed_test[final_columns]

# %%
# preprocessed_test.head()

# %% [markdown]
# ## Get One-hot Encoding of the Object Data Columns

# %% [markdown]
# ### Train Dataset

# %%
object_columns = [column for column in preprocessed_train.columns if preprocessed_train[column].dtype=='object']

# %%
preprocessed_train_encoded = pd.get_dummies(preprocessed_train, columns=object_columns)

# %%
preprocessed_train_encoded
# Out:
#       latitude  longitude  monthly_charges  churn  gender_Female  gender_Male  \
# 0    -0.498158  -0.371946         1.295086      0          False         True
# 1    -1.423199   1.358143        -1.516232      0           True        False
# 2     0.444907  -1.026476         0.965322      0          False         True
# 3     1.202459  -0.117674        -1.514566      0           True        False
# 4    -0.899465   0.660012         0.653879      0           True        False
# ...        ...        ...              ...    ...            ...          ...
# 6333  0.180098  -0.149465        -1.512901      0          False         True
# 6334 -1.035110   1.309279        -1.517897      1           True        False
# 6335 -0.844825   0.647366        -0.317092      0          False         True
# 6336  0.392377  -0.207744        -1.489584      0          False         True
# 6337  1.305974  -0.900267        -1.472930      1           True        False
#
#       senior_citizen_No  senior_citizen_Yes  partner_No  partner_Yes  ...  \
# 0                  True               False       False         True  ...
# 1                  True               False        True        False  ...
# 2                  True               False        True        False  ...
# 3                  True               False        True        False  ...
# 4                  True               False        True        False  ...
# ...                 ...                 ...         ...          ...  ...
# 6333               True               False       False         True  ...
# 6334               True               False       False         True  ...
# 6335               True               False       False         True  ...
# 6336               True               False        True        False  ...
# 6337               True               False       False         True  ...
#
#       streaming_movies_Yes  contract_Month-to-month  contract_One year  \
# 0                     True                     True              False
# 1                    False                    False               True
# 2                     True                     True              False
# 3                    False                    False              False
# 4                     True                     True              False
# ...                    ...                      ...                ...
# 6333                 False                    False               True
# 6334                 False                     True              False
# 6335                  True                    False               True
# 6336                 False                    False               True
# 6337                 False                     True              False
#
#       contract_Two year  paperless_billing_No  paperless_billing_Yes  \
# 0                 False                 False                   True
# 1                 False                 False                   True
# 2                 False                  True                  False
# 3                  True                  True                  False
# 4                 False                 False                   True
# ...                 ...                   ...                    ...
# 6333              False                 False                   True
# 6334              False                  True                  False
# 6335              False                 False                   True
# 6336              False                  True                  False
# 6337              False                  True                  False
#
#       payment_method_Bank transfer (automatic)  \
# 0                                         True
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6333                                      True
# 6334                                     False
# 6335                                     False
# 6336                                     False
# 6337                                     False
#
#       payment_method_Credit card (automatic)  payment_method_Electronic check  \
# 0                                      False                            False
# 1                                       True                            False
# 2                                      False                             True
# 3                                      False                            False
# 4                                      False                             True
# ...                                      ...                              ...
# 6333                                   False                            False
# 6334                                   False                            False
# 6335                                    True                            False
# 6336                                    True                            False
# 6337                                   False                            False
#
#       payment_method_Mailed check
# 0                           False
# 1                           False
# 2                           False
# 3                            True
# 4                           False
# ...                           ...
# 6333                        False
# 6334                         True
# 6335                        False
# 6336                        False
# 6337                         True
#
# [6338 rows x 47 columns]

# %%
preprocessed_train_encoded = preprocessed_train_encoded.rename(columns = lambda column: sentence_to_snake_case(column))

# %%
preprocessed_train_encoded
# Out:
#       latitude  longitude  monthly_charges  churn  gender_female  gender_male  \
# 0    -0.498158  -0.371946         1.295086      0          False         True
# 1    -1.423199   1.358143        -1.516232      0           True        False
# 2     0.444907  -1.026476         0.965322      0          False         True
# 3     1.202459  -0.117674        -1.514566      0           True        False
# 4    -0.899465   0.660012         0.653879      0           True        False
# ...        ...        ...              ...    ...            ...          ...
# 6333  0.180098  -0.149465        -1.512901      0          False         True
# 6334 -1.035110   1.309279        -1.517897      1           True        False
# 6335 -0.844825   0.647366        -0.317092      0          False         True
# 6336  0.392377  -0.207744        -1.489584      0          False         True
# 6337  1.305974  -0.900267        -1.472930      1           True        False
#
#       senior_citizen_no  senior_citizen_yes  partner_no  partner_yes  ...  \
# 0                  True               False       False         True  ...
# 1                  True               False        True        False  ...
# 2                  True               False        True        False  ...
# 3                  True               False        True        False  ...
# 4                  True               False        True        False  ...
# ...                 ...                 ...         ...          ...  ...
# 6333               True               False       False         True  ...
# 6334               True               False       False         True  ...
# 6335               True               False       False         True  ...
# 6336               True               False        True        False  ...
# 6337               True               False       False         True  ...
#
#       streaming_movies_yes  contract_month-to-month  contract_one_year  \
# 0                     True                     True              False
# 1                    False                    False               True
# 2                     True                     True              False
# 3                    False                    False              False
# 4                     True                     True              False
# ...                    ...                      ...                ...
# 6333                 False                    False               True
# 6334                 False                     True              False
# 6335                  True                    False               True
# 6336                 False                    False               True
# 6337                 False                     True              False
#
#       contract_two_year  paperless_billing_no  paperless_billing_yes  \
# 0                 False                 False                   True
# 1                 False                 False                   True
# 2                 False                  True                  False
# 3                  True                  True                  False
# 4                 False                 False                   True
# ...                 ...                   ...                    ...
# 6333              False                 False                   True
# 6334              False                  True                  False
# 6335              False                 False                   True
# 6336              False                  True                  False
# 6337              False                  True                  False
#
#       payment_method_bank_transfer_(automatic)  \
# 0                                         True
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 6333                                      True
# 6334                                     False
# 6335                                     False
# 6336                                     False
# 6337                                     False
#
#       payment_method_credit_card_(automatic)  payment_method_electronic_check  \
# 0                                      False                            False
# 1                                       True                            False
# 2                                      False                             True
# 3                                      False                            False
# 4                                      False                             True
# ...                                      ...                              ...
# 6333                                   False                            False
# 6334                                   False                            False
# 6335                                    True                            False
# 6336                                    True                            False
# 6337                                   False                            False
#
#       payment_method_mailed_check
# 0                           False
# 1                           False
# 2                           False
# 3                            True
# 4                           False
# ...                           ...
# 6333                        False
# 6334                         True
# 6335                        False
# 6336                        False
# 6337                         True
#
# [6338 rows x 47 columns]

# %%
preprocessed_train_encoded.to_csv('./data/preprocessed_train_encoded.csv')

# %% [markdown]
# ### Test Dataset

# %%
preprocessed_test_encoded = pd.get_dummies(preprocessed_test, columns=object_columns)

# %%
preprocessed_test_encoded
# Out:
#      latitude  longitude  monthly_charges  churn  gender_Female  gender_Male  \
# 0    1.077896  -1.383298         1.331726      0           True        False
# 1   -0.903949   0.703809        -1.479591      0          False         True
# 2   -0.863037   0.738054        -0.165534      1          False         True
# 3    0.495985  -1.031974         0.868725      0           True        False
# 4    0.898898  -0.799467         0.184215      1           True        False
# ..        ...        ...              ...    ...            ...          ...
# 700  0.565070  -1.052524         0.917023      0           True        False
# 701  1.201881  -1.740768        -1.489584      1          False         True
# 702  0.935368  -0.782134        -0.168865      0           True        False
# 703  1.791356  -1.034135        -1.532887      1          False         True
# 704  0.866432  -1.478761         1.213477      0           True        False
#
#      senior_citizen_No  senior_citizen_Yes  partner_No  partner_Yes  ...  \
# 0                False                True       False         True  ...
# 1                 True               False        True        False  ...
# 2                 True               False        True        False  ...
# 3                False                True        True        False  ...
# 4                 True               False        True        False  ...
# ..                 ...                 ...         ...          ...  ...
# 700               True               False       False         True  ...
# 701               True               False        True        False  ...
# 702               True               False       False         True  ...
# 703               True               False       False         True  ...
# 704              False                True        True        False  ...
#
#      streaming_movies_Yes  contract_Month-to-month  contract_One year  \
# 0                    True                    False               True
# 1                   False                    False              False
# 2                    True                     True              False
# 3                    True                     True              False
# 4                   False                     True              False
# ..                    ...                      ...                ...
# 700                  True                    False              False
# 701                 False                     True              False
# 702                 False                    False              False
# 703                 False                     True              False
# 704                  True                    False              False
#
#      contract_Two year  paperless_billing_No  paperless_billing_Yes  \
# 0                False                 False                   True
# 1                 True                  True                  False
# 2                False                  True                  False
# 3                False                  True                  False
# 4                False                  True                  False
# ..                 ...                   ...                    ...
# 700               True                 False                   True
# 701              False                  True                  False
# 702               True                 False                   True
# 703              False                  True                  False
# 704               True                  True                  False
#
#      payment_method_Bank transfer (automatic)  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 700                                     False
# 701                                      True
# 702                                      True
# 703                                     False
# 704                                     False
#
#      payment_method_Credit card (automatic)  payment_method_Electronic check  \
# 0                                     False                             True
# 1                                     False                            False
# 2                                     False                            False
# 3                                     False                             True
# 4                                     False                             True
# ..                                      ...                              ...
# 700                                   False                             True
# 701                                   False                            False
# 702                                   False                            False
# 703                                   False                            False
# 704                                    True                            False
#
#      payment_method_Mailed check
# 0                          False
# 1                          False
# 2                           True
# 3                          False
# 4                          False
# ..                           ...
# 700                        False
# 701                        False
# 702                        False
# 703                         True
# 704                        False
#
# [705 rows x 47 columns]

# %%
preprocessed_test_encoded = preprocessed_test_encoded.rename(columns = lambda column: sentence_to_snake_case(column))

# %%
preprocessed_test_encoded
# Out:
#      latitude  longitude  monthly_charges  churn  gender_female  gender_male  \
# 0    1.077896  -1.383298         1.331726      0           True        False
# 1   -0.903949   0.703809        -1.479591      0          False         True
# 2   -0.863037   0.738054        -0.165534      1          False         True
# 3    0.495985  -1.031974         0.868725      0           True        False
# 4    0.898898  -0.799467         0.184215      1           True        False
# ..        ...        ...              ...    ...            ...          ...
# 700  0.565070  -1.052524         0.917023      0           True        False
# 701  1.201881  -1.740768        -1.489584      1          False         True
# 702  0.935368  -0.782134        -0.168865      0           True        False
# 703  1.791356  -1.034135        -1.532887      1          False         True
# 704  0.866432  -1.478761         1.213477      0           True        False
#
#      senior_citizen_no  senior_citizen_yes  partner_no  partner_yes  ...  \
# 0                False                True       False         True  ...
# 1                 True               False        True        False  ...
# 2                 True               False        True        False  ...
# 3                False                True        True        False  ...
# 4                 True               False        True        False  ...
# ..                 ...                 ...         ...          ...  ...
# 700               True               False       False         True  ...
# 701               True               False        True        False  ...
# 702               True               False       False         True  ...
# 703               True               False       False         True  ...
# 704              False                True        True        False  ...
#
#      streaming_movies_yes  contract_month-to-month  contract_one_year  \
# 0                    True                    False               True
# 1                   False                    False              False
# 2                    True                     True              False
# 3                    True                     True              False
# 4                   False                     True              False
# ..                    ...                      ...                ...
# 700                  True                    False              False
# 701                 False                     True              False
# 702                 False                    False              False
# 703                 False                     True              False
# 704                  True                    False              False
#
#      contract_two_year  paperless_billing_no  paperless_billing_yes  \
# 0                False                 False                   True
# 1                 True                  True                  False
# 2                False                  True                  False
# 3                False                  True                  False
# 4                False                  True                  False
# ..                 ...                   ...                    ...
# 700               True                 False                   True
# 701              False                  True                  False
# 702               True                 False                   True
# 703              False                  True                  False
# 704               True                  True                  False
#
#      payment_method_bank_transfer_(automatic)  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 700                                     False
# 701                                      True
# 702                                      True
# 703                                     False
# 704                                     False
#
#      payment_method_credit_card_(automatic)  payment_method_electronic_check  \
# 0                                     False                             True
# 1                                     False                            False
# 2                                     False                            False
# 3                                     False                             True
# 4                                     False                             True
# ..                                      ...                              ...
# 700                                   False                             True
# 701                                   False                            False
# 702                                   False                            False
# 703                                   False                            False
# 704                                    True                            False
#
#      payment_method_mailed_check
# 0                          False
# 1                          False
# 2                           True
# 3                          False
# 4                          False
# ..                           ...
# 700                        False
# 701                        False
# 702                        False
# 703                         True
# 704                        False
#
# [705 rows x 47 columns]

# %%
preprocessed_test_encoded.to_csv('./data/preprocessed_test_encoded.csv')

# %% [markdown]
# ## Find Correlations and remove Perfectly correlated variables.

# %%
correlation_matrix = preprocessed_train_encoded.corr()

# %%
correlation_matrix.head()
# Out:
#                  latitude  longitude  monthly_charges     churn  \
# latitude         1.000000  -0.877206        -0.020473 -0.017142
# longitude       -0.877206   1.000000         0.025680  0.011172
# monthly_charges -0.020473   0.025680         1.000000 -0.188319
# churn           -0.017142   0.011172        -0.188319  1.000000
# gender_female   -0.008965   0.011392         0.009222 -0.002507
#
#                  gender_female  gender_male  senior_citizen_no  \
# latitude             -0.008965     0.008965           0.011495
# longitude             0.011392    -0.011392          -0.006748
# monthly_charges       0.009222    -0.009222          -0.213676
# churn                -0.002507     0.002507           0.022380
# gender_female         1.000000    -1.000000          -0.001139
#
#                  senior_citizen_yes  partner_no  partner_yes  ...  \
# latitude                  -0.011495    0.007535    -0.007535  ...
# longitude                  0.006748   -0.008153     0.008153  ...
# monthly_charges            0.213676   -0.108773     0.108773  ...
# churn                     -0.022380    0.304541    -0.304541  ...
# gender_female              0.001139   -0.001135     0.001135  ...
#
#                  streaming_movies_yes  contract_month-to-month  \
# latitude                    -0.000805                -0.009192
# longitude                    0.002081                 0.008550
# monthly_charges              0.625604                 0.058150
# churn                       -0.219195                 0.480506
# gender_female                0.004105                 0.007104
#
#                  contract_one_year  contract_two_year  paperless_billing_no  \
# latitude                  0.003901           0.006999              0.017724
# longitude                 0.002468          -0.012313             -0.021633
# monthly_charges           0.002542          -0.070189             -0.342714
# churn                    -0.252479          -0.319640              0.003653
# gender_female            -0.013011           0.004107             -0.007656
#
#                  paperless_billing_yes  \
# latitude                     -0.017724
# longitude                     0.021633
# monthly_charges               0.342714
# churn                        -0.003653
# gender_female                 0.007656
#
#                  payment_method_bank_transfer_(automatic)  \
# latitude                                         0.009987
# longitude                                       -0.013828
# monthly_charges                                  0.053603
# churn                                           -0.188348
# gender_female                                    0.016176
#
#                  payment_method_credit_card_(automatic)  \
# latitude                                      -0.010630
# longitude                                      0.003964
# monthly_charges                                0.029909
# churn                                         -0.185664
# gender_female                                  0.000807
#
#                  payment_method_electronic_check  payment_method_mailed_check
# latitude                               -0.003595                     0.004641
# longitude                               0.017923                    -0.010499
# monthly_charges                         0.266553                    -0.383736
# churn                                   0.162249                     0.184988
# gender_female                          -0.007845                    -0.007904
#
# [5 rows x 47 columns]

# %%
correlation_copy = correlation_matrix.copy(deep = True)

# %%
np.fill_diagonal(correlation_copy.values, 0)

# %%
correlation_copy.head()
# Out:
#                  latitude  longitude  monthly_charges     churn  \
# latitude         0.000000  -0.877206        -0.020473 -0.017142
# longitude       -0.877206   0.000000         0.025680  0.011172
# monthly_charges -0.020473   0.025680         0.000000 -0.188319
# churn           -0.017142   0.011172        -0.188319  0.000000
# gender_female   -0.008965   0.011392         0.009222 -0.002507
#
#                  gender_female  gender_male  senior_citizen_no  \
# latitude             -0.008965     0.008965           0.011495
# longitude             0.011392    -0.011392          -0.006748
# monthly_charges       0.009222    -0.009222          -0.213676
# churn                -0.002507     0.002507           0.022380
# gender_female         0.000000    -1.000000          -0.001139
#
#                  senior_citizen_yes  partner_no  partner_yes  ...  \
# latitude                  -0.011495    0.007535    -0.007535  ...
# longitude                  0.006748   -0.008153     0.008153  ...
# monthly_charges            0.213676   -0.108773     0.108773  ...
# churn                     -0.022380    0.304541    -0.304541  ...
# gender_female              0.001139   -0.001135     0.001135  ...
#
#                  streaming_movies_yes  contract_month-to-month  \
# latitude                    -0.000805                -0.009192
# longitude                    0.002081                 0.008550
# monthly_charges              0.625604                 0.058150
# churn                       -0.219195                 0.480506
# gender_female                0.004105                 0.007104
#
#                  contract_one_year  contract_two_year  paperless_billing_no  \
# latitude                  0.003901           0.006999              0.017724
# longitude                 0.002468          -0.012313             -0.021633
# monthly_charges           0.002542          -0.070189             -0.342714
# churn                    -0.252479          -0.319640              0.003653
# gender_female            -0.013011           0.004107             -0.007656
#
#                  paperless_billing_yes  \
# latitude                     -0.017724
# longitude                     0.021633
# monthly_charges               0.342714
# churn                        -0.003653
# gender_female                 0.007656
#
#                  payment_method_bank_transfer_(automatic)  \
# latitude                                         0.009987
# longitude                                       -0.013828
# monthly_charges                                  0.053603
# churn                                           -0.188348
# gender_female                                    0.016176
#
#                  payment_method_credit_card_(automatic)  \
# latitude                                      -0.010630
# longitude                                      0.003964
# monthly_charges                                0.029909
# churn                                         -0.185664
# gender_female                                  0.000807
#
#                  payment_method_electronic_check  payment_method_mailed_check
# latitude                               -0.003595                     0.004641
# longitude                               0.017923                    -0.010499
# monthly_charges                         0.266553                    -0.383736
# churn                                   0.162249                     0.184988
# gender_female                          -0.007845                    -0.007904
#
# [5 rows x 47 columns]

# %%
perfect_corr_cols = correlation_copy.index[(correlation_copy == 1.0).any(axis=1)].tolist()

# %%
perfect_corr_cols
# Out:
# ['phone_service_no',
#  'multiple_lines_no_phone_service',
#  'internet_service_no',
#  'online_security_no_internet_service',
#  'online_backup_no_internet_service',
#  'device_protection_no_internet_service',
#  'tech_support_no_internet_service',
#  'streaming_tv_no_internet_service',
#  'streaming_movies_no_internet_service']

# %%
perfect_corr_cols2 = [column for column in perfect_corr_cols if column not in ['phone_service_no', 'internet_service_no']]

# %%
perfect_corr_cols2
# Out:
# ['multiple_lines_no_phone_service',
#  'online_security_no_internet_service',
#  'online_backup_no_internet_service',
#  'device_protection_no_internet_service',
#  'tech_support_no_internet_service',
#  'streaming_tv_no_internet_service',
#  'streaming_movies_no_internet_service']

# %%
preprocessed_train_encoded.drop(columns=perfect_corr_cols2).to_csv('./data/preprocessed_train_encoded_no_corr.csv')

# %%
preprocessed_test_encoded.drop(columns=perfect_corr_cols2).to_csv('./data/preprocessed_test_encoded_no_corr.csv')

# %%
preprocessed_train_encoded.drop(columns=perfect_corr_cols2).columns
# Out:
# Index(['latitude', 'longitude', 'monthly_charges', 'churn', 'gender_female',
#        'gender_male', 'senior_citizen_no', 'senior_citizen_yes', 'partner_no',
#        'partner_yes', 'dependents_no', 'dependents_yes', 'phone_service_no',
#        'phone_service_yes', 'multiple_lines_no', 'multiple_lines_yes',
#        'internet_service_dsl', 'internet_service_fiber_optic',
#        'internet_service_no', 'online_security_no', 'online_security_yes',
#        'online_backup_no', 'online_backup_yes', 'device_protection_no',
#        'device_protection_yes', 'tech_support_no', 'tech_support_yes',
#        'streaming_tv_no', 'streaming_tv_yes', 'streaming_movies_no',
#        'streaming_movies_yes', 'contract_month-to-month', 'contract_one_year',
#        'contract_two_year', 'paperless_billing_no', 'paperless_billing_yes',
#        'payment_method_bank_transfer_(automatic)',
#        'payment_method_credit_card_(automatic)',
#        'payment_method_electronic_check', 'payment_method_mailed_check'],
#       dtype='object')
